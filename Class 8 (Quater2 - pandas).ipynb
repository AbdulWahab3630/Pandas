# %% [markdown]
# # Hierarchical Indexing

# %%
import numpy as np
import pandas as pd

data = pd.Series(np.random.randn(9), index=[["a", "a", "a", "b", "b", "c", "c", "d", "d"],
                                            [1,2,3,1,3,1,2,2,3]])
display(data)
# Out:
# a  1    0.665610
#    2    0.703964
#    3    0.041599
# b  1   -0.186030
#    3    0.686565
# c  1    0.102203
#    2   -0.972260
# d  2   -3.321155
#    3    0.424970
# dtype: float64

# %%
print(data["a"])
# Out:
# 1    0.665610
# 2    0.703964
# 3    0.041599
# dtype: float64

# %%
print(data["b":"c"])
# Out:
# b  1   -0.186030
#    3    0.686565
# c  1    0.102203
#    2   -0.972260
# dtype: float64

# %%
print(data.loc[:, 2])
# Out:
# a    0.703964
# c   -0.972260
# d   -3.321155
# dtype: float64

# %%
print(data)
df = data.unstack()
display(df)
# Out:
# a  1    0.665610
#    2    0.703964
#    3    0.041599
# b  1   -0.186030
#    3    0.686565
# c  1    0.102203
#    2   -0.972260
# d  2   -3.321155
#    3    0.424970
# dtype: float64
#           1         2         3
# a  0.665610  0.703964  0.041599
# b -0.186030       NaN  0.686565
# c  0.102203 -0.972260       NaN
# d       NaN -3.321155  0.424970

# %%
df.stack()
# Out:
# a  1    0.665610
#    2    0.703964
#    3    0.041599
# b  1   -0.186030
#    3    0.686565
# c  1    0.102203
#    2   -0.972260
# d  2   -3.321155
#    3    0.424970
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(12).reshape(4,3), index=[["a","a","b","b"],[1,2,1,2]], columns=[["Ohio","Ohio","Colarado"],
                                                                                              ["Green","Red", "Green"]])
display(frame)
frame.index.names=["key1","key2"]
frame.columns.names=["State","Color"]
display(frame)
display(frame["Ohio"])
# Out:
#      Ohio     Colarado
#     Green Red    Green
# a 1     0   1        2
#   2     3   4        5
# b 1     6   7        8
#   2     9  10       11
# State      Ohio     Colarado
# Color     Green Red    Green
# key1 key2
# a    1        0   1        2
#      2        3   4        5
# b    1        6   7        8
#      2        9  10       11
# Color      Green  Red
# key1 key2
# a    1         0    1
#      2         3    4
# b    1         6    7
#      2         9   10

# %%
frame= frame.swaplevel("key1","key2").sort_index()
display(frame)
# Out:
# State      Ohio     Colarado
# Color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %% [markdown]
# # Summary Statistics by Level

# %%
display(frame)
# Out:
# State      Ohio     Colarado
# Color     Green Red    Green
# key2 key1
# 1    a        0   1        2
#      b        6   7        8
# 2    a        3   4        5
#      b        9  10       11

# %%
display(frame.sum(level="key2"))
# Out:
# State  Ohio     Colarado
# Color Green Red    Green
# key2
# 1         6   8       10
# 2        12  14       16

# %%
display(frame.sum(level="Color", axis=1))
# Out:
# Color      Green  Red
# key2 key1
# 1    a         2    1
#      b        14    7
# 2    a         8    4
#      b        20   10

# %%
display(frame.sum(level="key1"))
# Out:
# State  Ohio     Colarado
# Color Green Red    Green
# key1
# a         3   5        7
# b        15  17       19

# %%
frame = pd.DataFrame({"a": range(7),
                      "b": range(7,0,-1),
                      "c": ["one","one","one","two","two","two","two"],
                      "d": [0,1,2,0,1,2,3]}
                    )
display(frame)
# Out:
#    a  b    c  d
# 0  0  7  one  0
# 1  1  6  one  1
# 2  2  5  one  2
# 3  3  4  two  0
# 4  4  3  two  1
# 5  5  2  two  2
# 6  6  1  two  3

# %%
 display(frame.set_index(["c","d"]))
# Out:
#        a  b
# c   d
# one 0  0  7
#     1  1  6
#     2  2  5
# two 0  3  4
#     1  4  3
#     2  5  2
#     3  6  1

# %%
display(frame.set_index(["c","d"], drop=False))
# Out:
#        a  b    c  d
# c   d
# one 0  0  7  one  0
#     1  1  6  one  1
#     2  2  5  one  2
# two 0  3  4  two  0
#     1  4  3  two  1
#     2  5  2  two  2
#     3  6  1  two  3

# %% [markdown]
# # Combining and Merging Datasets

# %%
df1 = pd.DataFrame({"key1":["b", "b", "a", "c", "a", "a", "b"],
                    "Data1": range(7)})
df2 = pd.DataFrame({"key1":["a", "b", "d"],
                    "Data1": range(3)})
pd.merge(df1,df2, on="key1")
# Out:
#   key1  Data1_x  Data1_y
# 0    b        0        1
# 1    b        1        1
# 2    b        6        1
# 3    a        2        0
# 4    a        4        0
# 5    a        5        0

# %%
df3 = pd.DataFrame({"lkey":["b", "b", "a", "c", "a", "a", "b"],
                    "Data1": range(7)})
df4 = pd.DataFrame({"rkey":["a", "b", "d"],
                    "Data1": range(3)})
pd.merge(df3,df4, left_on="lkey", right_on="rkey")
# Out:
#   lkey  Data1_x rkey  Data1_y
# 0    b        0    b        1
# 1    b        1    b        1
# 2    b        6    b        1
# 3    a        2    a        0
# 4    a        4    a        0
# 5    a        5    a        0

# %%
left1 = pd.DataFrame({"key": ["a", "b", "a", "a", "b", "c"],
                      "value": range(6)})
right1 = pd.DataFrame({"group_val": [3.5, 7]}, index=["a", "b"])
print(left1)
print(right1)
# Out:
#   key  value
# 0   a      0
# 1   b      1
# 2   a      2
# 3   a      3
# 4   b      4
# 5   c      5
#    group_val
# a        3.5
# b        7.0

# %%
pd.merge(left1,right1, left_on="key", right_index=True)            # By Default Inner Join
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0

# %%
pd.merge(left1,right1, left_on="key", right_index=True, how="outer")
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0
# 5   c      5        NaN

# %%
pd.merge(left1,right1, left_on="key", right_index=True, how="right")
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0

# %%
pd.merge(left1,right1, left_on="key", right_index=True, how="left")
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 1   b      1        7.0
# 2   a      2        3.5
# 3   a      3        3.5
# 4   b      4        7.0
# 5   c      5        NaN

# %%
df2 = pd.DataFrame({"city": ["new york", "chicago", "orlando"],
                    "temperature": [21,14,35]})
df2 = pd.DataFrame({"city": [ "chicago", "new york", "orlando"],
                    "temperature": [65,68,71]})

# %%
pd.merge(df1,df2, on="city", suffixes=["_left", "_right"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-67-bcb7470a0199> in <module>
# ----> 1 pd.merge(df1,df2, on="city", suffixes=["_left", "_right"])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     527         (self.left_join_keys,
#     528          self.right_join_keys,
# --> 529          self.join_names) = self._get_merge_keys()
#     530
#     531         # validate the merge keys dtypes. We may need to coerce
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in _get_merge_keys(self)
#     844                         right_keys.append(rk)
#     845                     if lk is not None:
# --> 846                         left_keys.append(left._get_label_or_level_values(lk))
#     847                         join_names.append(lk)
#     848                     else:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1704             values = self.axes[axis].get_level_values(key)._values
#    1705         else:
# -> 1706             raise KeyError(key)
#    1707
#    1708         # Check for duplicates
#
# KeyError: 'city'

# %%
df3 = pd.DataFrame({"city": ["new york", "chicago", "orlando", "baltimore"],
                    "temperature": [21,14,35,32]})
df4 = pd.DataFrame({"city": [ "chicago", "new york", "san francisco"],
                    "humadity": [65,68,75]})
display(df3)
display(df4)
# Out:
#         city  temperature
# 0   new york           21
# 1    chicago           14
# 2    orlando           35
# 3  baltimore           32
#             city  humadity
# 0        chicago        65
# 1       new york        68
# 2  san francisco        75

# %%
pd.merge(df3,df4, on="city")
# Out:
#        city  temperature  humadity
# 0  new york           21        68
# 1   chicago           14        65

# %%
pd.merge(df3,df4, on="city", how="outer", indicator=True)
# Out:
#             city  temperature  humadity      _merge
# 0       new york         21.0      68.0        both
# 1        chicago         14.0      65.0        both
# 2        orlando         35.0       NaN   left_only
# 3      baltimore         32.0       NaN   left_only
# 4  san francisco          NaN      75.0  right_only

# %%
pd.merge(df3,df4, on="city", how="left")
# Out:
#         city  temperature  humadity
# 0   new york           21      68.0
# 1    chicago           14      65.0
# 2    orlando           35       NaN
# 3  baltimore           32       NaN

# %%
pd.merge(df3,df4, on="city", how="right")
# Out:
#             city  temperature  humadity
# 0       new york         21.0        68
# 1        chicago         14.0        65
# 2  san francisco          NaN        75

# %% [markdown]
# # Concatinating along an axis

# %%
s1 = pd.Series([1,2], index=["a", "b"])
s2 = pd.Series([3,4,5], index=["c", "d","e"])
s3 = pd.Series([6,7], index=["f", "g"])

# %%
pd.concat([s1,s2,s3])
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# f    6
# g    7
# dtype: int64

# %%
pd.concat([s1,s2,s3], axis=1, sort= True)
# Out:
#      0    1    2
# a  1.0  NaN  NaN
# b  2.0  NaN  NaN
# c  NaN  3.0  NaN
# d  NaN  4.0  NaN
# e  NaN  5.0  NaN
# f  NaN  NaN  6.0
# g  NaN  NaN  7.0

# %%
s4 = pd.concat([s1,s3])
display(s4)
# Out:
# a    1
# b    2
# f    6
# g    7
# dtype: int64

# %%
pd.concat([s1,s4], axis =1 , join="inner")
# Out:
#    0  1
# a  1  1
# b  2  2

# %%
pd.concat([s1,s4], axis =1 , join_axes=[["a","c","b","a"]])
# Out:
#      0    1
# a  1.0  1.0
# c  NaN  NaN
# b  2.0  2.0
# a  1.0  1.0

# %%
df1 = pd.DataFrame(np.random.randn(3,4), columns=["a","b","c","d"])
df2 = pd.DataFrame(np.random.randn(2,3), columns=["b","d","a"])
display(df1)
display(df2)
# Out:
#           a         b         c         d
# 0 -0.051366 -0.213408  0.718665 -0.769792
# 1  1.764942  0.036201 -1.356844 -0.034638
# 2 -0.022888  1.644118 -0.659398 -0.899220
#           b         d         a
# 0  1.200528 -0.492136 -1.470591
# 1  0.025540 -1.412815 -0.284147

# %%
pd.concat([df1,df2], ignore_index=True, sort=True)
# Out:
#           a         b         c         d
# 0 -0.051366 -0.213408  0.718665 -0.769792
# 1  1.764942  0.036201 -1.356844 -0.034638
# 2 -0.022888  1.644118 -0.659398 -0.899220
# 3 -1.470591  1.200528       NaN -0.492136
# 4 -0.284147  0.025540       NaN -1.412815

# %% [markdown]
# # Pivoting Long to Wide Format

# %%
df = pd.read_csv("macro.csv")
display(df)
# Out:
#      year   quarter   realgdp   realcons   realinv   realgovt   realdpi  \
# 0  1959.0       1.0  2710.349     1707.4   286.898    470.045    1886.9
# 1  1959.0       2.0  2778.801     1733.7   310.859    481.301    1919.7
# 2  1959.0       3.0  2775.488     1751.8   289.226    491.260    1916.4
# 3  1959.0       4.0  2785.204     1753.7   299.356    484.052    1931.3
# 4  1960.0       1.0  2847.699     1770.5   331.722    462.199    1955.5
#
#      cpi     m1   tbilrate   unemp      pop   infl   realint
# 0  28.98  139.7       2.82     5.8  177.146   0.00       0.00
# 1  29.15  141.7       3.08     5.1  177.830   2.34       0.74
# 2  29.35  140.5       3.82     5.3  178.657   2.74       1.09
# 3  29.37  140.0       4.33     5.6  179.386   0.27       4.06
# 4  29.54  139.6       3.50     5.2  180.007   2.31       1.19

# %%
periods = pd.PeriodIndex(year = df.year, quarter= df.quarter, name="date")
columns = pd.Index(["realgdp", "infl", "unemp"], name="item")
data = data.reindex(columns=columns)
data.head()
data.index= periods.to_timestamp("D", "end")
ldata = data.stack().reset_index().rename(columns={0: 'value'})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-e0bde5c810ac> in <module>
# ----> 1 periods = pd.PeriodIndex(year = df.year, quarter= df.quarter, name="date")
#       2 columns = pd.Index(["realgdp", "infl", "unemp"], name="item")
#       3 data = data.reindex(columns=columns)
#       4 data.head()
#       5 data.index= periods.to_timestamp("D", "end")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'quarter'

# %%
df = pd.DataFrame({"key": ["foo","bar","baz"],
                    "A":[1,2,3],
                    "B":[4,5,6],
                    "C":[7,8,9]})
display(df)
# Out:
#    key  A  B  C
# 0  foo  1  4  7
# 1  bar  2  5  8
# 2  baz  3  6  9

# %%
melted = pd.melt(df, ["key"])
melted
# Out:
#    key variable  value
# 0  foo        A      1
# 1  bar        A      2
# 2  baz        A      3
# 3  foo        B      4
# 4  bar        B      5
# 5  baz        B      6
# 6  foo        C      7
# 7  bar        C      8
# 8  baz        C      9

# %%
melted.pivot(index="key", columns="variable")
# Out:
#          value
# variable     A  B  C
# key
# bar          2  5  8
# baz          3  6  9
# foo          1  4  7
